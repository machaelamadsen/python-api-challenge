# %% [markdown]
# # VacationPy
# ---
#
# ## Starter Code to Import Libraries and Load the Weather and Coordinates Data

# %%
# Dependencies and Setup
import hvplot.pandas
import pandas as pd
import requests

# Import API key
from api_keys import geoapify_key

# %%
# Load the CSV file created in Part 1 into a Pandas DataFrame
city_data_df = pd.read_csv("../output_data/cities.csv")

# Display sample data
city_data_df.head()
# Out:
#    City_ID          City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        0     adamstown -25.0660 -130.1015     73.15        86          95
# 1        1      khandyga  62.6667  135.6000    -27.72       100          67
# 2        2  puerto ayora  -0.7393  -90.3518     84.16        92          70
# 3        3      bilibino  68.0546  166.4372    -19.21       100         100
# 4        4      funafuti  -8.5243  179.1942     82.40       100          75
#
#    Wind Speed Country        Date
# 0       18.28      PN  1699915953
# 1        2.86      RU  1699915953
# 2        5.01      EC  1699915953
# 3        4.65      RU  1699915948
# 4       10.36      TV  1699915954

# %% [markdown]
# ---
#
# ### Step 1: Create a map that displays a point for every city in the `city_data_df` DataFrame. The size of the point should be the humidity in each city.

# %%
# %%capture --no-display
humidity = city_data_df["Humidity"].astype(int)
# Configure the map plot
map_plot_1 = city_data_df.hvplot.points(
"Lng",
"Lat",
geo = True,
tiles = "OSM",
frame_width = 700,
frame_height = 500,
size = "Humidity",
scale = .5,
color = "City")

# Display the map
map_plot_1
# Out:
# :Overlay
#    .WMTS.I   :WMTS   [Longitude,Latitude]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity)

# %% [markdown]
# ### Step 2: Narrow down the `city_data_df` DataFrame to find your ideal weather condition

# %%
# Narrow down cities that fit criteria and drop any results with null values
city_data_df = city_data_df.loc[(city_data_df["Max Temp"] < 40) & (city_data_df["Max Temp"]>30)]

# Drop any rows with null values
city_data_df = city_data_df.dropna(how="any")

# Display sample data
city_data_df
# Out:
#      City_ID                 City      Lat       Lng  Max Temp  Humidity  \
# 9          9              yorkton  51.2167 -102.4677     37.24        70
# 14        14       puerto natales -51.7236  -72.4875     38.32        71
# 17        17            grytviken -54.2811  -36.5092     36.55        98
# 27        27           st. john's  47.5649  -52.7093     32.97        80
# 47        47            makar'yev  57.8797   43.8069     38.19        78
# 49        49               albany  42.6001  -73.9662     38.59        69
# 57        57               dryden  49.7833  -92.7503     35.89        75
# 63        63                 hami  42.8000   93.4500     37.60        28
# 92        92                chela  34.0690  104.4619     32.38        89
# 93        93           isafjordur  66.0755  -23.1240     34.83        84
# 95        95  grand falls-windsor  48.9332  -55.6649     33.51        75
# 107      107             la sarre  48.8002  -79.1996     33.55       100
# 110      110            flin flon  54.7682 -101.8650     31.84        86
# 121      121              murashi  59.3999   48.9615     38.21        92
# 133      133             akureyri  65.6835  -18.0878     35.53        80
# 153      153          mount pearl  47.5166  -52.7813     32.14        80
# 154      154   villa la angostura -40.7617  -71.6463     37.44        98
# 170      170                 amos  48.5669  -78.1162     32.50        99
# 282         100        3.87      RU  1699916003
# 304         100        7.31      RU  1699916007
# 310         100       14.97      CA  1699916008
# 329           1        6.91      NO  1699916014
# 351           0       20.13      KZ  1699916018
# 369           5        6.06      CN  1699915820
# 373          56       20.24      JP  1699916021
# 386         100        8.66      RU  1699916023
# 389          49       12.17      KZ  1699916023
# 391         100       17.43      RU  1699916023
# 405           0        1.68      CN  1699916026
# 413         100        8.90      RU  1699916027
# 418         100        5.46      RU  1699916028
# 438          40        1.14      IS  1699915999
# 461          73        7.09      UA  1699916036
# 472          85       13.80      RU  1699916037
# 501          97        1.12      KZ  1699916042
# 510          91        4.74      UA  1699916044
# 515         100       15.32      RU  1699916045
# 516          40        2.30      CA  1699915816
# 517         100       11.99      RU  1699915994
# 541          31        8.34      KZ  1699916049
# 542           3        1.39      CN  1699916050

# %% [markdown]
# ### Step 3: Create a new DataFrame called `hotel_df`.

# %%
# Use the Pandas copy function to create DataFrame called hotel_df to store the city, country, coordinates, and humidity
hotel_df = city_data_df[["City", "Country", "Lat", "Lng", "Humidity"]].copy()

# Add an empty column, "Hotel Name," to the DataFrame so you can store the hotel found using the Geoapify API
hotel_df["Hotel Name"] = ""

# Display sample data
hotel_df.head()
# Out:
#               City Country      Lat       Lng  Humidity Hotel Name
# 9          yorkton      CA  51.2167 -102.4677        70
# 14  puerto natales      CL -51.7236  -72.4875        71
# 17       grytviken      GS -54.2811  -36.5092        98
# 27      st. john's      CA  47.5649  -52.7093        80
# 47       makar'yev      RU  57.8797   43.8069        78

# %% [markdown]
# ### Step 4: For each city, use the Geoapify API to find the first hotel located within 10,000 metres of your coordinates.

# %%
# Set parameters to search for a hotel
radius = 10000
limit = 1
params = {
    "radius": radius,
    "limit": limit,
    "apiKey":geoapify_key  
  
}

# Print a message to follow up the hotel search
print("Starting hotel search")

# Iterate through the hotel_df DataFrame
for index, row in hotel_df.iterrows():
    # get latitude, longitude from the DataFrame
    Lat = hotel_df["Lat"]
    Lng = hotel_df["Lng"]
    
    # Add filter and bias parameters with the current city's latitude and longitude to the params dictionary
    params["filter"] = f"circle:{Lat},{Lng},{radius}"
    params["bias"] = f"proximity:{Lat},{Lng}"
    #params["categories"] = accommodation.hotel
    # Set base URL
    base_url = "https://api.geoapify.com/v2/places"


    # Make and API request using the params dictionaty
    name_address = requests.get(base_url, params=params)
    
    # Convert the API response to JSON format
    name_address = name_address.json()
    
    # Grab the first hotel from the results and store the name in the hotel_df DataFrame
    try:
        hotel_df.loc[index, "Hotel Name"] = name_address["features"][0]["properties"]["name"]
    except (KeyError, IndexError):
        # If no hotel is found, set the hotel name as "No hotel found".
        hotel_df.loc[index, "Hotel Name"] = "No hotel found"
        
    # Log the search results
    print(f"{hotel_df.loc[index, 'City']} - nearest hotel: {hotel_df.loc[index, 'Hotel Name']}")

# Display sample data
hotel_df
# Out:
# 121              murashi      RU  59.3999   48.9615        92  No hotel found
# 133             akureyri      IS  65.6835  -18.0878        80  No hotel found
# 153          mount pearl      CA  47.5166  -52.7813        80  No hotel found
# 154   villa la angostura      AR -40.7617  -71.6463        98  No hotel found
# 170                 amos      CA  48.5669  -78.1162        99  No hotel found
# 176            boguchany      RU  58.3814   97.4531        97  No hotel found
# 196              achinsk      RU  56.2694   90.4993        85  No hotel found
# 204           ulsteinvik      NO  62.3432    5.8487        75  No hotel found
# 228         podporozh'ye      RU  60.9112   34.1706        95  No hotel found
# 233           constantia      RO  44.1833   28.6500        51  No hotel found
# 264            kochenevo      RU  55.0218   82.2020        94  No hotel found
# 268       yuzhno-kurilsk      RU  44.0306  145.8556        80  No hotel found
# 269              pryluky      UA  50.5932   32.3876        88  No hotel found
# 275              klyuchi      RU  52.2667   79.1667        89  No hotel found
# 282             pikalevo      RU  59.5183   34.1664        99  No hotel found
# 304           tyukalinsk      RU  55.8732   72.1967        91  No hotel found
# 310          kapuskasing      CA  49.4169  -82.4331        93  No hotel found
# 329         kristiansund      NO  63.1115    7.7320        69  No hotel found
# 351               aktobe      KZ  50.2797   57.2072        81  No hotel found
# 369               jining      CN  35.4050  116.5814        40  No hotel found
# 373               nemuro      JP  43.3236  145.5750        65  No hotel found
# 386              vysokiy      RU  58.3500   60.0500        98  No hotel found
# 389           dzhalagash      KZ  45.0833   64.6667        67  No hotel found
# 391             pochinok      RU  54.4068   32.4407        96  No hotel found
# 405                 aksu      CN  41.1231   80.2644        45  No hotel found
# 413            koryazhma      RU  61.3143   47.1691        98  No hotel found
# 418               tevriz      RU  57.5090   72.4042        95  No hotel found
# 438          egilsstadir      IS  65.2653  -14.3948        93  No hotel found
# 461               ovruch      UA  51.3246   28.8035        89  No hotel found
# 472             nevel'sk      RU  46.6733  141.8633        72  No hotel found
# 501      zhanga buqtyrma      KZ  49.6295   83.5248        94  No hotel found
# 510            derazhnya      UA  49.2692   27.4338        79  No hotel found
# 515          mesyagutovo      RU  55.5303   58.2528        91  No hotel found
# 516             smithers      CA  54.7804 -127.1743        93  No hotel found
# 517              vytegra      RU  61.0064   36.4481        89  No hotel found
# 541          zhezqazghan      KZ  47.7833   67.7667        83  No hotel found
# 542             jinchang      CN  38.4953  102.1739        36  No hotel found

# %% [markdown]
# ### Step 5: Add the hotel name and the country as additional information in the hover message for each city in the map.

# %%
# %%capture --no-display

# Configure the map plot
map_plot_2 = hotel_df.hvplot.points(
"Lng",
"Lat",
geo = True,
tiles = "OSM",
frame_width = 700,
frame_height = 500,
size = "Humidity",
scale = .5,
color = "City",
hover_cols = ["Hotel Name", "Country"])
# Display the map
map_plot_2
# Out:
# :Overlay
#    .WMTS.I   :WMTS   [Longitude,Latitude]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity,Hotel Name,Country)
